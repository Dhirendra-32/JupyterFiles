# %%
import os 
os.getcwd()#getchwd() gives current directory name

# %%
os.chdir('C:\\Users\\dt321\\Desktop\\Jupyter files\\flight_data')#via chdir() we change the currect working direcotry by giving path

# %%
os.getcwd()#proof working directory has changed
# Out:
# 'C:\\Users\\dt321\\Desktop\\Jupyter files\\flight_data'

# %%
import pandas as pd
import numpy as np

# %%
#read csv file from current working direcotry

# %%
dataFrame1=pd.read_csv('tips.csv')

# %%
type(dataFrame1)
# Out:
# pandas.core.frame.DataFrame

# %%
dataFrame1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#function on data frame

# %%
len(dataFrame1) #no of records
# Out:
# 244

# %%
len(dataFrame1.columns)#nof column
# Out:
# 7

# %%
dataFrame1.head()#bydefault will give top five records of database or dataframe and specfic can passed as argument
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataFrame1.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
dataFrame1.tail(1)#no 1 will give last record of data set
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 243       18.78  3.0  Female     No  Thur  Dinner     2

# %%
dataFrame1.head(8)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4

# %%
dataFrame1.tail(7)#last 7 record of data set
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
#acessing specific colmn of data set

# %%
dataFrame1[['total_bill','sex','smoker','time']]#showing only specific column of data set
# Out:
#      total_bill     sex smoker    time
# 0         16.99  Female     No  Dinner
# 1         10.34    Male     No  Dinner
# 2         21.01    Male     No  Dinner
# 3         23.68    Male     No  Dinner
# 4         24.59  Female     No  Dinner
# ..          ...     ...    ...     ...
# 239       29.03    Male     No  Dinner
# 240       27.18  Female    Yes  Dinner
# 241       22.67    Male    Yes  Dinner
# 242       17.82    Male     No  Dinner
# 243       18.78  Female     No  Dinner
#
# [244 rows x 4 columns]

# %%
dataFrame1[dataFrame1['time']=='Dinner']#datafram[dataframe.colname......]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
#to find out tip >5 when time is dinner

# %%
dataFrame1[(dataFrame1['time']=='Dinner') & (dataFrame1['tip']>5) ]
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 44        30.40   5.60    Male     No  Sun  Dinner     4
# 47        32.40   6.00    Male     No  Sun  Dinner     4
# 52        34.81   5.20  Female     No  Sun  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 116       29.93   5.07    Male     No  Sun  Dinner     4
# 155       29.85   5.14  Female     No  Sun  Dinner     5
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2
# 181       23.33   5.65    Male    Yes  Sun  Dinner     2
# 183       23.17   6.50    Male    Yes  Sun  Dinner     4
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3
# 239       29.03   5.92    Male     No  Sat  Dinner     3

# %%
dataFrame1.time
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: object

# %%
dataFrame1[(dataFrame1['time']=='Dinner') & (dataFrame1['tip']>5) ].tail(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# 211       25.89  5.16    Male    Yes  Sat  Dinner     4
# 212       48.33  9.00    Male     No  Sat  Dinner     4
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3

# %%
#or : record where size is 5 or total_bill is 45

# %%
dataFrame1[(dataFrame1['size']>5)|(dataFrame1['total_bill']>45) ]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 125       29.80   4.20  Female     No  Thur   Lunch     6
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 143       27.05   5.00  Female     No  Thur   Lunch     6
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
len(dataFrame1[(dataFrame1['size']>5)|(dataFrame1['total_bill']>45) ])#length of previus data set
# Out:
# 8

# %%
dataFrame1.head(2).groupby('sex').size()
# Out:
# sex
# Female    1
# Male      1
# dtype: int64

# %%
dataFrame1.groupby(['smoker','sex','day']).agg({'tip':np.mean,'size':np.size})
# Out:
#                          tip  size
# smoker sex    day
# No     Female Fri   3.125000     2
#               Sat   2.724615    13
#               Sun   3.329286    14
#               Thur  2.459600    25
#        Male   Fri   2.500000     2
#               Sat   3.256563    32
#               Sun   3.115349    43
#               Thur  2.941500    20
# Yes    Female Fri   2.682857     7
#               Sat   2.868667    15
#               Sun   3.500000     4
#               Thur  2.990000     7
#        Male   Fri   2.741250     8
#               Sat   2.879259    27
#               Sun   3.521333    15
#               Thur  3.058000    10

# %%
#using dplyr package when when we modify existing datafram acccording to our requirement

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dt321\\Desktop\\Jupyter files\\flight_data'

# %%
stats=pd.read_csv('DemographicData.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
len(stats)
# Out:
# 195

# %%
len(stats.columns)
# Out:
# 5

# %%
stats.info()# will show structure of datafran stat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.to_csv('stats.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats.columns=['CountryName','CountryCode','BirthRate','InternerUSer','IncomeGroup']#there are two ways to rename the column
#stats.rename(column={key:pair})

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternerUSer  \
# 0                   Aruba         ABW     10.244          78.9
# 1             Afghanistan         AFG     35.253           5.9
# 2                  Angola         AGO     45.985          19.1
# 3                 Albania         ALB     12.877          57.2
# 4    United Arab Emirates         ARE     11.044          88.0
# ..                    ...         ...        ...           ...
# 190           Yemen, Rep.         YEM     32.947          20.0
# 191          South Africa         ZAF     20.850          46.5
# 192      Congo, Dem. Rep.         COD     42.394           2.2
# 193                Zambia         ZMB     40.471          15.4
# 194              Zimbabwe         ZWE     35.715          18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[1:4]
# Out:
#    CountryName CountryCode  BirthRate  InternerUSer          IncomeGroup
# 1  Afghanistan         AFG     35.253           5.9           Low income
# 2       Angola         AGO     45.985          19.1  Upper middle income
# 3      Albania         ALB     12.877          57.2  Upper middle income

# %%
stats[1:4][['CountryName','BirthRate']]
# Out:
#    CountryName  BirthRate
# 1  Afghanistan     35.253
# 2       Angola     45.985
# 3      Albania     12.877

# %%
stats[(stats['CountryName']=='India')|(stats['CountryName']=='Pakistan') ]# it can be written differently like below steps
# Out:
#     CountryName CountryCode  BirthRate  InternerUSer          IncomeGroup
# 80        India         IND     20.291          15.1  Lower middle income
# 135    Pakistan         PAK     29.582          10.9  Lower middle income

# %%
stats[stats['CountryName'].isin(['India','Pakistan'])]
# Out:
#     CountryName CountryCode  BirthRate  InternerUSer          IncomeGroup
# 80        India         IND     20.291          15.1  Lower middle income
# 135    Pakistan         PAK     29.582          10.9  Lower middle income

# %%
stats['Mycal']=stats.BirthRate*stats.InternerUSer

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternerUSer  \
# 0                   Aruba         ABW     10.244          78.9
# 1             Afghanistan         AFG     35.253           5.9
# 2                  Angola         AGO     45.985          19.1
# 3                 Albania         ALB     12.877          57.2
# 4    United Arab Emirates         ARE     11.044          88.0
# ..                    ...         ...        ...           ...
# 190           Yemen, Rep.         YEM     32.947          20.0
# 191          South Africa         ZAF     20.850          46.5
# 192      Congo, Dem. Rep.         COD     42.394           2.2
# 193                Zambia         ZMB     40.471          15.4
# 194              Zimbabwe         ZWE     35.715          18.5
#
#              IncomeGroup     Mycal
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
stats.sort_values(['Mycal'],ascending=0)
# Out:
#             CountryName CountryCode  BirthRate  InternerUSer  \
# 96               Kuwait         KWT     20.575         75.46
# 128             Nigeria         NGA     40.045         38.00
# 85               Israel         ISR     21.300         70.80
# 188  West Bank and Gaza         PSE     30.394         46.60
# 91                Kenya         KEN     35.194         39.00
# ..                  ...         ...        ...           ...
# 64               Guinea         GIN     37.337          1.60
# 11              Burundi         BDI     44.151          1.30
# 172         Timor-Leste         TLS     35.755          1.10
# 52              Eritrea         ERI     34.800          0.90
# 117             Myanmar         MMR     18.119          1.60
#
#              IncomeGroup      Mycal
# 96           High income  1552.5895
# 128  Lower middle income  1521.7100
# 85           High income  1508.0400
# 188  Lower middle income  1416.3604
# 91   Lower middle income  1372.5660
# ...

# %%
stats.drop('Mycal',axis=1,inplace = True)

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternerUSer  \
# 0                   Aruba         ABW     10.244          78.9
# 1             Afghanistan         AFG     35.253           5.9
# 2                  Angola         AGO     45.985          19.1
# 3                 Albania         ALB     12.877          57.2
# 4    United Arab Emirates         ARE     11.044          88.0
# ..                    ...         ...        ...           ...
# 190           Yemen, Rep.         YEM     32.947          20.0
# 191          South Africa         ZAF     20.850          46.5
# 192      Congo, Dem. Rep.         COD     42.394           2.2
# 193                Zambia         ZMB     40.471          15.4
# 194              Zimbabwe         ZWE     35.715          18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
import seaborn as sns #help to create data visualization matplotlib

# %%
sns.lmplot(data=stats,x='InternerUSer',y='BirthRate',fit_reg=False,col='IncomeGroup')

# %%
#how to join multiple ,we have three data frame df1,df2,df3

# %%
df1= pd.DataFrame(np.array([['a',5,10],['b',4,61],['c',24,19]]),columns=['name','attri1','attri2'])

# %%
df2= pd.DataFrame(np.array([['a',6,11],['b',5,62],['c',25,20]]),columns=['name','attri1','attri2'])

# %%
df3 = pd.DataFrame(np.array([['a',7,12],['b',6,63],['c',26,21]]),columns=['name','attri1','attri2'])

# %%
df1,df2,df3
# Out:
# (  name attri1 attri2
#  0    a      5     10
#  1    b      4     61
#  2    c     24     19,   name attri1 attri2
#  0    a      6     11
#  1    b      5     62
#  2    c     25     20,   name attri1 attri2
#  0    a      7     12
#  1    b      6     63
#  2    c     26     21)

# %%
df1
# Out:
#   name attri1 attri2
# 0    a      5     10
# 1    b      4     61
# 2    c     24     19

# %%
df2
# Out:
#   name attri1 attri2
# 0    a      6     11
# 1    b      5     62
# 2    c     25     20

# %%
df3
# Out:
#   name attri1 attri2
# 0    a      7     12
# 1    b      6     63
# 2    c     26     21

# %%
#joining these three data frame with innr join

# %%
pd.merge(df1,df2, on='name')#joining two frame df1 and df2 based on one colmnb
# Out:
#   name attri1_x attri2_x attri1_y attri2_y
# 0    a        5       10        6       11
# 1    b        4       61        5       62
# 2    c       24       19       25       20

# %%
pd.merge(pd.merge(df1,df2, on='name',how = 'right'),df3,on ='name',how='right')
# Out:
#   name attri1_x attri2_x attri1_y attri2_y attri1 attri2
# 0    a        5       10        6       11      7     12
# 1    b        4       61        5       62      6     63
# 2    c       24       19       25       20     26     21

# %%
df1.merge(df2, on ='name').merge(df3,on ='name',how='right')
# Out:
#   name attri1_x attri2_x attri1_y attri2_y attri1 attri2
# 0    a        5       10        6       11      7     12
# 1    b        4       61        5       62      6     63
# 2    c       24       19       25       20     26     21

# %%
pd.merge(df1,df2, on=['name'])
# Out:
#   name attri1_x attri2_x attri1_y attri2_y
# 0    a        5       10        6       11
# 1    b        4       61        5       62
# 2    c       24       19       25       20

# %%
from dfply import*

# %%
flight_data_frame = pd.read_csv("flight_data.csv")

# %%
flight_data_frame
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
#datafram name >>syntac

# %%
(flight_data_frame>>select(X.origin , X.dest,X.hour)).head()#just like sequal syntax
# Out:
#   origin dest  hour
# 0    EWR  IAH     5
# 1    LGA  IAH     5
# 2    JFK  MIA     5
# 3    JFK  BQN     5
# 4    LGA  ATL     6

# %%
(flight_data_frame>>
select(~X.origin ,~X.dest,~X.hour))#mean exclusion of origin dest and hour
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum  air_time  distance  \
# ...

# %%
(flight_data_frame>>mask(X.month==1 ,X.day==1,X.origin =='JFK',X.hour>10))
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 151  2013      1    1     848.0            1835      853.0    1001.0
# 258  2013      1    1    1059.0            1100       -1.0    1210.0
# 265  2013      1    1    1111.0            1115       -4.0    1222.0
# 266  2013      1    1    1112.0            1100       12.0    1440.0
# 272  2013      1    1    1124.0            1100       24.0    1435.0
# ..    ...    ...  ...       ...             ...        ...       ...
# 832  2013      1    1    2326.0            2130      116.0     131.0
# 833  2013      1    1    2327.0            2250       37.0      32.0
# 835  2013      1    1    2353.0            2359       -6.0     425.0
# 836  2013      1    1    2353.0            2359       -6.0     418.0
# 837  2013      1    1    2356.0            2359       -3.0     425.0
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
(flight_data_frame>>arrange(X.distance,X.hour,ascending= True)).head(50)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 275945  2013      7   27       NaN             106        NaN       NaN
# 3083    2013      1    4    1240.0            1200       40.0    1333.0
# 3901    2013      1    5    1155.0            1200       -5.0    1241.0
# 3426    2013      1    4    1829.0            1615      134.0    1937.0
# 10235   2013      1   12    1613.0            1617       -4.0    1708.0
# 16328   2013      1   19    1617.0            1617        0.0    1722.0
# 22334   2013      1   26    1621.0            1617        4.0    1705.0
# 112694  2013      2    2    1610.0            1617       -7.0    1702.0
# 118425  2013      2    9    1619.0            1617        2.0    1706.0
# 137872  2013      3    2    1926.0            1929       -3.0    2011.0
# 150994  2013      3   16    1947.0            1950       -3.0    2055.0
# 157540  2013      3   23    1946.0            1950       -4.0    2030.0
# ...

# %%
(flight_data_frame>>mutate(newdistance=X.distance/100,carrier_origin = X.carrier+X.origin)).head(70)
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   2013      1    1     517.0             515        2.0     830.0
# 1   2013      1    1     533.0             529        4.0     850.0
# 2   2013      1    1     542.0             540        2.0     923.0
# 3   2013      1    1     544.0             545       -1.0    1004.0
# 4   2013      1    1     554.0             600       -6.0     812.0
# ..   ...    ...  ...       ...             ...        ...       ...
# 65  2013      1    1     659.0             700       -1.0    1008.0
# 66  2013      1    1     659.0             705       -6.0     907.0
# 67  2013      1    1     659.0             700       -1.0     959.0
# 68  2013      1    1     701.0             700        1.0    1123.0
# 69  2013      1    1     702.0             700        2.0    1058.0
#
#     sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0              819       11.0      UA  ...   N14228    EWR  IAH    227.0
# ...

# %%
((flight_data_frame>>mask(X.year==2013))>>mutate(newdistance=X.distance/100,carrier_origin = X.carrier+X.origin)).head(70)
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   2013      1    1     517.0             515        2.0     830.0
# 1   2013      1    1     533.0             529        4.0     850.0
# 2   2013      1    1     542.0             540        2.0     923.0
# 3   2013      1    1     544.0             545       -1.0    1004.0
# 4   2013      1    1     554.0             600       -6.0     812.0
# ..   ...    ...  ...       ...             ...        ...       ...
# 65  2013      1    1     659.0             700       -1.0    1008.0
# 66  2013      1    1     659.0             705       -6.0     907.0
# 67  2013      1    1     659.0             700       -1.0     959.0
# 68  2013      1    1     701.0             700        1.0    1123.0
# 69  2013      1    1     702.0             700        2.0    1058.0
#
#     sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0              819       11.0      UA  ...   N14228    EWR  IAH    227.0
# ...

# %%
(flight_data_frame>>group_by(X.origin)).head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute      time_hour
# 0      1400     5      15  1/1/2013 5:00
# ...

# %%
(flight_data_frame>>group_by(X.origin))>>summarise(mean_dis=X.distance.mean())
# Out:
#   origin     mean_dis
# 0    EWR  1056.742790
# 1    JFK  1266.249077
# 2    LGA   779.835671

# %%
(flight_data_frame>>mask(X.hour>10)>>mutate(speed=X.distance/(X.air_time*60))>>group_by(X.origin)>>summarise(mean_speed=X.speed.mean())>>arrange(X.mean_speed,ascending=False))
# Out:
#   origin  mean_speed
# 0    EWR    0.109777
# 1    JFK    0.109427
# 2    LGA    0.107362
